# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanbir0095/Tanbir/blob/main/median_percentile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Data_Set = 'https://drive.google.com/file/d/108NqCdwBPoNHbM5cf1N5ZlT0aC6nXWsK/view?usp=drive_link'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/DM &ML/income.csv',names=["name","income"], skiprows=[0])
df
# Out:
#         name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
df.describe()
# Out:
#             Income$
# count  7.000000e+00
# mean   1.433929e+06
# std    3.777283e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    7.750000e+03
# max    1.000000e+07

# %%
df.income.quantile(0)
# Out:
# 4000.0

# %%
df.income.quantile(0.25,interpolation="higher")
# Out:
# 6000

# %%
df.income.quantile(.25, interpolation="lower")
# Out:
# 5000

# %%
# outlayer
percentile_99=df.income.quantile(.99)
percentile_99
# Out:
# 9400479.999999994

# %%
df_no_outlier = df[df.income<= percentile_99]
df_no_outlier
# Out:
#     name  income
# 0    Rob    5000
# 1  Rafiq    6000
# 2   Nina    4000
# 3  Sofia    7500
# 4  Mohan    8000
# 5    Tao    7000

# %%
df[df.income > percentile_99]
# Out:
#         name    income
# 6  Elon Musk  10000000

# %%
df
# Out:
#         Name   Income$
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
df['Income$'][3] = np.NaN
# Out:
# <ipython-input-24-4f8deada6581>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Income$'][3] = np.NaN

# %%
df
# Out:
#         Name     Income$
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia         NaN
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
df['Income$'].mean()
# Out:
# 1671666.6666666667

# %%
df_new = df.fillna(df['Income$'].mean())
df_new
# Out:
#         Name       Income$
# 0        Rob  5.000000e+03
# 1      Rafiq  6.000000e+03
# 2       Nina  4.000000e+03
# 3      Sofia  1.671667e+06
# 4      Mohan  8.000000e+03
# 5        Tao  7.000000e+03
# 6  Elon Musk  1.000000e+07

# %%
df_new = df.fillna(df['Income$'].median())
df_new
# Out:
#         Name     Income$
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia      6500.0
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0
